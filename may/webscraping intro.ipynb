# %%
import requests

# %%
request = requests.get('http://example.com/')

# %%
print(request)
# Out:
# <Response [200]>

# %%
requests.models.Response
# Out:
# requests.models.Response

# %%
request.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(request.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
res = requests.get('https://en.wikipedia.org/wiki/Richard_Feynman')

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
for item in soup.select('.toctext'):
    print(item.text)
# Out:
# Early life
# Religion
# Education
# Manhattan Project
# Cornell
# Caltech years
# Personal and political life
# Physics
# Pedagogy
# Surely You're Joking, Mr. Feynman!
# Challenger disaster
# Recognition and awards
# Death
# Popular legacy
# Bibliography
# Selected scientific works
# Textbooks and lecture notes
# Popular works
# Audio and video recordings
# Notes
# References
# Further reading
# Articles
# Books
# Films and plays
# External links

# %%
toc
# Out:
# <function __main__.<lambda>(item)>

# %%
import re

# %%
pattern = r'\d{4}'

# %%
search_date = re.search(pattern, soup.text)

# %%
search_date.group()
# Out:
# '1965'

# %%
image = soup.select('.infobox-image')[0]

# %%
image
# Out:
# <td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Richard_Feynman_Nobel.jpg" title="Feynman in a jacket and tie, smiling"><img alt="Feynman in a jacket and tie, smiling" data-file-height="396" data-file-width="280" decoding="async" height="311" src="//upload.wikimedia.org/wikipedia/en/thumb/4/42/Richard_Feynman_Nobel.jpg/220px-Richard_Feynman_Nobel.jpg" srcset="//upload.wikimedia.org/wikipedia/en/4/42/Richard_Feynman_Nobel.jpg 1.5x" width="220"/></a><div class="infobox-caption">Feynman <abbr title="circa">c.</abbr> 1965</div></td>

# %% [markdown]
# <img src = '//upload.wikimedia.org/wikipedia/en/thumb/4/42/Richard_Feynman_Nobel.jpg/220px-Richard_Feynman_Nobel.jpg'>

# %%
image_type = requests.get('https://upload.wikimedia.org/wikipedia/en/thumb/4/42/Richard_Feynman_Nobel.jpg/220px-Richard_Feynman_Nobel.jpg')

# %%
image_type.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00d\x00d\x00\x00\xff\xfe\x00KFile source: https://en.wikipedia.org/wiki/File:Richard_Feynman_Nobel.jpg\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xc0\x00\x0b\x08\x017\x00\xdc\x01\x01"\x00\xff\xc4\x00\x1c\x00\x00\x00\x07\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x04\x05\x06\x07\x01\x08\xff\xc4\x00E\x10\x00\x01\x03\x02\x04\x03\x06\x03\x04\x08\x03\x08\x02\x03\x00\x00\x01\x02\x03\x11\x00\x04\x05\x12!1\x06AQ\x07\x13"aq\x812\x91\xa1\x14#\xb1\xc1\x08BRbr\xd1\xe1\xf0\x15$\x82\x163CS\x92\xa2\xb2\xf1\x17\xd2%4\xc2\xff\xda\x00\x08\x01\x01\x00\x00?\x00\xf5M\n\x14(P\xa1B\x85\n\x14\t\xa1\\5\xca)\xfc\xe95m\xa5\x19:\r\xe8\x11\xb5qCmi=\x81\x07A<\xe8\x8a\xda\rs-\x15@\x8fOJ\x04\x08\xa2\xabM\xc8\x8d\xa92\x9e\x9aW\x08\x8e\xbf:\x98\xa1B\x85\n\x14(P\xae\x12#S\x14\xc9X\x8b%\xf0\
# ...

# %%
image_file = open('richar_feyman.jpg', 'wb')

# %%
image_file.write(image_type.content)
# Out:
# 13478

# %%
image_file.close()
