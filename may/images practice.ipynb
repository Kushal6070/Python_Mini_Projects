# %%
from PIL import Image

# %%
feyman = Image.open('richar_feyman.jpg')

# %%
feyman.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
feyman.size
# Out:
# (220, 311)

# %%
feyman.crop((0,0,110,250))
# Out:
# <PIL.Image.Image image mode=L size=110x250 at 0x17A0FD4A9D0>

# %%
feyman
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=220x311 at 0x17A1015F280>

# %%
nose = feyman.crop((110,160,40,40))

# %%
feyman.paste(im=nose, box=(0,0))

# %%
feyman
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=220x311 at 0x17A1015F280>
