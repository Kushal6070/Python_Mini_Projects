# %%
from PIL import Image

# %%
words = Image.open('word_matrix.png')

# %%
mask = Image.open('mask.png')

# %%
words.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
mask = mask.resize((1015,559))

# %%
mask.putalpha(220)

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x2CB97459C70>
